# %% [markdown]
# # Support Vector Machine com Normalização Standard e Balanceamento Undersampling

# %%
from pandas import read_csv

# Carregando os dados
arquivo = 'dados_dataset/dados_limpos.csv'
dados = read_csv(arquivo)
print("dataset carregado")
# Out:
# dataset carregado

# %% [markdown]
# ## Balanceamento Undersampling

# %%
from sklearn import preprocessing
import pandas as pd

# 1. Transformar a coluna Attrition (0 e 1) em um formato que o LabelEncoder reconhece 
label_encoder = preprocessing.LabelEncoder()
dados['Attrition'] = label_encoder.fit_transform(dados['Attrition'])

# 2. Contagem das classes
count_class_0, count_class_1 = dados.Attrition.value_counts()

# 3. Separando as classes
target_class_0 = dados[dados['Attrition'] == 0]
target_class_1 = dados[dados['Attrition'] == 1]

# 4. Realizando o undersampling na classe majoritária (0)
dados_class_0_under = target_class_0.sample(count_class_1)

# 5. Combinando as classes 
dados_under = pd.concat([dados_class_0_under, target_class_1], axis=0)

# Verificação da nova distribuição
print('Random undersampling:')
print(dados_under.Attrition.value_counts())
# Out:
# Random undersampling:
# Attrition
# 0    237
# 1    237
# Name: count, dtype: int64

# %% [markdown]
# ## Normalização Standard

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# 1. Separando os dados
X = dados_under.drop('Attrition', axis=1).values
Y = dados_under['Attrition'].values

# 2. Divisão 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# 3. Padronização 
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Tamanho do X_train após balanceamento:", X_train_scaled.shape)
print("Dados de Treino Padronizados (5 primeiras linhas):\n", X_train_scaled[0:5,:])
# Out:
# Tamanho do X_train após balanceamento: (379, 44)
# Dados de Treino Padronizados (5 primeiras linhas):
#  [[-0.04363199 -0.15077357 -0.77463724  0.09216299  0.30283857 -1.22307791
#   -0.7990218  -0.86221021  0.30434534 -1.05520757  0.33402994 -0.66185254
#    0.68547772 -0.46759974  0.32281941  1.5094896  -1.20165048  0.19093481
#    0.35793555 -0.87358047 -1.10187368 -0.62938836 -1.02766069 -0.55398245
#   -1.49643451  0.76103    -0.70151692  1.18912268 -0.36705659 -0.63947004
#   -0.21670562 -0.36241314  0.77405175 -0.18082463  1.8320267  -0.22973415
#   -0.3088296  -0.17289102 -0.47595926 -0.53769475 -0.3088296   1.18268093
#   -0.836392   -0.78279369]
#  [-0.47315215 -1.06379424  1.06565223  2.03270588  1.17898986  1.10678945
#    1.85737524 -0.86221021 -1.47022211 -0.67410123  0.97487063 -1.05318189
#    0.42671671 -0.46759974  0.32281941 -0.79735136 -1.06968133  0.95266423
#    0.35793555 -0.87358047 -1.10187368 -0.62938836 -1.02766069 -0.55398245
#    0.66825511 -1.31400864 -0.70151692 -0.84095613 -0.36705659 -0.63947004
#   -0.21670562 -0.36241314  0.77405175  5.53022001 -0.54584357 -0.22973415
#   -0.3088296  -0.17289102 -0.47595926 -0.53769475 -0.3088296   1.18268093
#   -0.836392   -0.78279369]
#  [-0.36577211 -1.66420457  0.45222241  1.06243443 -0.57331272  0.330167
#    0.52917672  0.07144027  1.19162907 -0.34487085 -0.73287567 -0.27052319
#   -1.12584935 -0.46759974  0.32281941  0.35606912 -0.27786644  0.19093481
#   -0.98520874 -0.20268483 -0.49751749 -0.62938836 -0.18462303 -0.55398245
#    0.66825511 -1.31400864  1.42548237  1.18912268 -0.36705659 -0.63947004
#   -0.21670562 -0.36241314  0.77405175 -0.18082463 -0.54584357 -0.22973415
#   -0.3088296  -0.17289102 -0.47595926  1.85979126 -0.3088296  -0.84553659
#   -0.836392   -0.78279369]
#  [-0.36577211  1.70255913  0.20685048  1.06243443  1.17898986 -0.30083874
#    1.85737524  0.07144027  0.30434534 -0.27570289  1.31223594  2.0774529
#   -0.86708834 -0.46759974  1.23586834 -0.79735136 -0.54180474 -0.5707946
#    0.35793555 -0.37040874 -0.49751749 -0.29716247 -0.46563558 -0.55398245
#   -1.49643451 -1.31400864  1.42548237 -0.84095613 -0.36705659 -0.63947004
#    4.61455498 -0.36241314  0.77405175 -0.18082463 -0.54584357 -0.22973415
#   -0.3088296  -0.17289102 -0.47595926  1.85979126 -0.3088296   1.18268093
#   -0.836392   -0.78279369]
#  [ 0.27850812  1.03764191 -0.03852145 -0.87810846 -0.57331272  0.23308919
#    0.52917672 -0.86221021  1.19162907 -0.26114122 -0.02955476 -0.27052319
#    0.94423872 -0.46759974  1.23586834  1.5094896  -0.01392814 -2.09425343
#    1.70107983 -0.20268483 -0.49751749 -0.62938836 -0.18462303 -0.55398245
#    0.66825511  0.76103    -0.70151692  1.18912268 -0.36705659 -0.63947004
#   -0.21670562 -0.36241314  0.77405175 -0.18082463 -0.54584357 -0.22973415
#   -0.3088296  -0.17289102  2.10102016 -0.53769475 -0.3088296  -0.84553659
#   -0.836392   -0.78279369]]

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# 1. Instancia o modelo SVM
modelo = SVC(kernel='linear', random_state=42)

# 2. Treina usando os dados padronizados
modelo.fit(X_train_scaled, y_train)

# 3. Faz a previsão no conjunto de teste 
y_pred = modelo.predict(X_test_scaled)

# 4. Avalia
print("Relatório de Classificação - SVM:")
print(classification_report(y_test, y_pred))
# Out:
# Relatório de Classificação - SVM:
#               precision    recall  f1-score   support
#
#            0       0.74      0.62      0.67        47
#            1       0.68      0.79      0.73        48
#
#     accuracy                           0.71        95
#    macro avg       0.71      0.70      0.70        95
# weighted avg       0.71      0.71      0.70        95

# %%
import csv
import os
import time
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# tempo de predição
inicio = time.time()
y_pred = modelo.predict(X_test_scaled)
fim = time.time()

# Calcular as métricas
acuracia = accuracy_score(y_test, y_pred)
precisao = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
especificidade = tn / (tn + fp)

tempo = fim - inicio

# SALVANDO RESULTADOS

filename = 'resultados_experimentos.csv'

# Nomes das colunas
fields = ['Modelo', 'Descrição', 'Acurácia', 'Precisão', 'Recall', 'Specificity', 'F1 Score', 'Tempo em Segundo'] 
    
rows = [[
    'SVM', 
    'normalizacao standard, balanceamento under', 
    f"{acuracia:.8f}", 
    f"{precisao:.8f}", 
    f"{recall:.8f}", 
    f"{especificidade:.8f}", 
    f"{f1:.8f}", 
    f"{tempo:.8f}"
]]


file_exists = os.path.isfile(filename)

with open(filename, 'a', newline='', encoding='utf-8') as f:
    
    write = csv.writer(f)
    
    if not file_exists:
        write.writerow(fields) 
        
    # Escreve a linha com os resultados do modelo
    write.writerows(rows)
    
    f.close()

print(f"Resultados salvos com sucesso em {filename}")
# Out:
# Resultados salvos com sucesso em resultados_experimentos.csv
